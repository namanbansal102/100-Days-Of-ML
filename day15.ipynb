# %%
# Working with csv File Formats
import pandas as pd

# %%
# Sep Operator
# as sTab Separator file is Separated By Tab
df=pd.read_csv('aug_train.csv',sep=',')
# as Generally Seperated By , Separator
df
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
# Naming The Columns in Pandas DataFrame if names not given In DataFrame
df=pd.read_csv("aug_train.csv",names=['custom_id','zip_code'])

# %%
# Naming The Index To Enrollment Id
df=pd.read_csv('aug_train.csv',index_col=['enrollee_id'])

# %%
# using The Row as A Header Parameter
pd.read_csv('aug_train.csv',header=3)
# Out:
#        11561   city_21  0.624 Unnamed: 3   No relevent experience  \
# 0      33241  city_115  0.789        NaN   No relevent experience
# 1        666  city_162  0.767       Male  Has relevent experience
# 2      21651  city_176  0.764        NaN  Has relevent experience
# 3      28806  city_160  0.920       Male  Has relevent experience
# 4        402   city_46  0.762       Male  Has relevent experience
# ...      ...       ...    ...        ...                      ...
# 19150   7386  city_173  0.878       Male   No relevent experience
# 19151  31398  city_103  0.920       Male  Has relevent experience
# 19152  24576  city_103  0.920       Male  Has relevent experience
# 19153   5756   city_65  0.802       Male  Has relevent experience
# 19154  23834   city_67  0.855        NaN   No relevent experience
#
#        Full time course        Graduate             STEM    5 Unnamed: 9  \
# 0                   NaN        Graduate  Business Degree   <1        NaN
# ...

# %%
# using The 1 Column Id
pd.read_csv('aug_train.csv',usecols=['city'])
# Out:
#            city
# 0      city_103
# 1       city_40
# 2       city_21
# 3      city_115
# 4      city_162
# ...         ...
# 19153  city_173
# 19154  city_103
# 19155  city_103
# 19156   city_65
# 19157   city_67
#
# [19158 rows x 1 columns]

# %%
# using The Squeeze Operator For Getting 1 Column
pd.read_csv('aug_train.csv',usecols=['gender'])
# Out:
#       gender
# 0       Male
# 1       Male
# 2        NaN
# 3        NaN
# 4       Male
# ...      ...
# 19153   Male
# 19154   Male
# 19155   Male
# 19156   Male
# 19157    NaN
#
# [19158 rows x 1 columns]

# %%
# Using The Python Skip Row Parameter To Skip Row in a Pandas DataFrame
# as We Can Write a Function To Skip Rows
# pd.read_csv('aug_train.csv',skiprows=[0,1,2,3,4])
pd.read_csv('aug_train.csv',skiprows=lambda x:x/5==0)
# Out:
#         8949  city_103   0.92  Male  Has relevent experience  \
# 0      29725   city_40  0.776  Male   No relevent experience
# 1      11561   city_21  0.624   NaN   No relevent experience
# 2      33241  city_115  0.789   NaN   No relevent experience
# 3        666  city_162  0.767  Male  Has relevent experience
# 4      21651  city_176  0.764   NaN  Has relevent experience
# ...      ...       ...    ...   ...                      ...
# 19152   7386  city_173  0.878  Male   No relevent experience
# 19153  31398  city_103  0.920  Male  Has relevent experience
# 19154  24576  city_103  0.920  Male  Has relevent experience
# 19155   5756   city_65  0.802  Male  Has relevent experience
# 19156  23834   city_67  0.855   NaN   No relevent experience
#
#           no_enrollment        Graduate             STEM  >20 Unnamed: 9  \
# 0         no_enrollment        Graduate             STEM   15      50-99
# 1      Full time course        Graduate             STEM    5        NaN
# ...

# %%
# For Skipping The Rows in Pandas DataFrame
# As This is Useful For Getting Number of Rows
pd.read_csv('aug_train.csv',nrows=100)
# Out:
#     enrollee_id      city  city_development_index gender  \
# 0          8949  city_103                   0.920   Male
# 1         29725   city_40                   0.776   Male
# 2         11561   city_21                   0.624    NaN
# 3         33241  city_115                   0.789    NaN
# 4           666  city_162                   0.767   Male
# ..          ...       ...                     ...    ...
# 95        12081   city_65                   0.802   Male
# 96         7364  city_160                   0.920    NaN
# 97        11184   city_74                   0.579    NaN
# 98         7016   city_65                   0.802   Male
# 99         8695   city_11                   0.550   Male
#
#         relevent_experience enrolled_university education_level  \
# 0   Has relevent experience       no_enrollment        Graduate
# 1    No relevent experience       no_enrollment        Graduate
# 2    No relevent experience    Full time course        Graduate
# ...

# %%
# Encoding Parameter
# As There Are Some Datasets With Different Encodings as Default Encoding is utf-8
pd.read_csv('aug_train.csv',encoding='utf-8')
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
# Skip Bad Lines
pd.read_csv('aug_train.csv',on_bad_lines='skip')
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
# Changing The Dtype Parameter From Float to int and from int to String anyway
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  object
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  object
#  4   relevent_experience     19158 non-null  object
#  5   enrolled_university     18772 non-null  object
#  6   education_level         18698 non-null  object
#  7   major_discipline        16345 non-null  object
#  8   experience              19093 non-null  object
#  9   company_size            13220 non-null  object
#  10  company_type            13018 non-null  object
#  11  last_new_job            18735 non-null  object
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  float64
# ...

# %%
df.sample()
# Out:
#        enrollee_id      city  city_development_index gender  \
# 11960        22924  city_175                   0.776   Male
#
#           relevent_experience enrolled_university education_level  \
# 11960  No relevent experience    Full time course        Graduate
#
#       major_discipline experience company_size company_type last_new_job  \
# 11960             STEM          3      100-500      Pvt Ltd            1
#
#        training_hours  target
# 11960              41     0.0

# %%
# Changing The Dtype of Variable in Pandas DataFrame
pd.read_csv('aug_train.csv',dtype={'target':'int'})
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
 # handling Dates Way of Changing To Date Type Object 
# pd.read_csv('aug_train.csv',parse_dates=['get_date'])

# %%
# use a Convertor parameter to Change Type of Paramter
def rename(text):
    if text=="Graduate":
        return "UnderGraduate"
    else:
        return "Any Other Course"
pd.read_csv('aug_train.csv',converters={'education_level':rename})
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university   education_level  \
# 0      Has relevent experience       no_enrollment     UnderGraduate
# 1       No relevent experience       no_enrollment     UnderGraduate
# ...

# %%
# using na Parameter To get Change
pd.read_csv('aug_train.csv',na_values=['Male'])
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920    NaN
# 1            29725   city_40                   0.776    NaN
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767    NaN
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878    NaN
# 19154        31398  city_103                   0.920    NaN
# 19155        24576  city_103                   0.920    NaN
# 19156         5756   city_65                   0.802    NaN
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
for chunk in pd.read_csv('aug_train.csv',chunksize=5000):
    print(chunk.shape)
# Out:
# (5000, 14)
# (5000, 14)
# (5000, 14)
# (4158, 14)
